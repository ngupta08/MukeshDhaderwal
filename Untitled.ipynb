# %%
my_list = [123, "123","Nishant"]

# %%
my_list.append("Mahima")

# %%
index = my_list.index("Nishant")
my_list[index] = "Nishnat Gupta"

# %%
my_dict = {"abc":123,"xyz":123}

# %%
my_dict["pqr"] = 123

# %%
type(my_dict["xyz"])
# Out:
# int

# %%
del my_dict["abc"]

# %%
my_set = {"abc","pqr","abc"}

# %%
my_set.add("rst")

# %%
my_str = "abcdefghijkl"

# %%
my_str = "DATA PLAY"

# %%
x = input()
# Out:
#  100

# %%
x = -15 
if x > 0 :
    print('posiitve')
elif x == -15:
    print('Special Case')
elif x< 0:
    print("Ngetaive")
# Out:
# Special Case

# %%
x = int(input())
if x<33:
    print("Fail")
elif x < 75:
    print("Distinction")
else:
    print("H")
# Out:
#  100
# H

# %%
numbers = [0,1,2,3,4,5,6]

for num in numbers[::-1]:
    print(num)
# Out:
#   Cell In[39], line 1
#     numbers = [0,1,2,3,4,5,6]for num in
#                              ^
# SyntaxError: invalid syntax

# %%
marks = float(input())

# %%
for row in range(4):
    for column in range(4-row):
        print("*", end=" ")
    print("")
# Out:
# * * * *
# * * *
# * *
# *
